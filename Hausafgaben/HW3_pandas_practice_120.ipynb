# %% [markdown]
# <a href="https://colab.research.google.com/github/Alister44/DTA_2026_DE/blob/main/Hausafgaben/HW3_pandas_practice_120.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas: Praktikum mit 120 Aufgaben
#
# **Syntax-Training • Niveau: einfach**
#
# ---
#
# Dieses Notebook enthält **120 kurze Aufgaben** zu den pandas-Funktionen, die wir in der Vorlesung behandelt haben. Ziel ist es, die Syntax zu trainieren, bis die Befehle automatisch von der Hand gehen.
#
# ## Daten
# Wir arbeiten mit den Daten einer Online-Buchhandlung — Datei `bookstore_sales.csv` (400 Bestellungen über 8 Monate).
#
# | Spalte | Beschreibung |
# |---|---|
# | `order_id` | Bestellnummer |
# | `date` | Bestelldatum |
# | `city` | Stadt des Kunden |
# | `book_title` | Buchtitel |
# | `genre` | Genre |
# | `unit_price` | Preis pro Buch (€) |
# | `quantity` | Anzahl der Bücher |
# | `discount_pct` | Rabatt in Prozent |
# | `total` | Gesamtbetrag der Bestellung (€) |
# | `channel` | Bestellkanal (Website / App / Telefon) |
# | `manager` | Manager, der die Bestellung bearbeitet hat |
# | `rating` | Kundenbewertung (3-5) |
#
# ## So arbeitest du
# - Führe jede Zelle aus (Shift + Enter)
# - Wenn du die Syntax vergessen hast — schau ins Notebook der Vorlesung
# - Hab keine Angst vor Fehlern, experimentiere!
#
# ---

# %% [markdown]
# ## Vorbereitung
#
# Führe zuerst diese Zelle aus — sie importiert pandas und lädt die Daten. Alle Aufgaben arbeiten mit der Variable `df`.

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Alister44/DTA_2026_DE/refs/heads/main/data/bookstore_sales.csv")
df.head()
# Out:
#    order_id        date    city              book_title      genre  \
# 0      5275  2024-06-25  Харків                 Sapiens      Наука
# 1      5386  2024-08-09   Одеса  Гордість і упередження  Романтика
# 2      5100  2024-02-21  Харків  Гордість і упередження  Романтика
# 3      5352  2024-08-18  Дніпро                 Sapiens      Наука
# 4      5032  2024-01-27    Київ            Шерлок Холмс   Детектив
#
#    unit_price  quantity  discount_pct  total               channel manager  \
# 0         410         2             0  820.0               Телефон   Ірина
# 1         240         2             0  480.0               Телефон   Ірина
# 2         240         1            15  204.0                  Сайт   Ірина
# 3         410         1             0  410.0  Мобільний застосунок  Віктор
# 4         250         1            20  200.0                  Сайт    Олег
#
#    rating
# 0       5
# 1       5
# 2       5
# 3       3
# 4       3

# %% [markdown]
# ## Kapitel 1. Erster Blick auf die Daten (Aufgaben 1-15)
#
# Befehle: `head()`, `tail()`, `shape`, `columns`, `info()`, `describe()`, `dtypes`.

# %% [markdown]
# **Aufgabe 1.** Gib die ersten 5 Zeilen der Tabelle aus.

# %%
# Aufgabe 1:

# %% [markdown]
# **Aufgabe 2.** Gib die ersten 10 Zeilen der Tabelle aus.
#
# > 💡 head() nimmt eine Zahl entgegen — wie viele Zeilen angezeigt werden sollen.

# %%
# Aufgabe 2:

# %% [markdown]
# **Aufgabe 3.** Gib die letzten 5 Zeilen der Tabelle aus.
#
# > 💡 Verwende die Methode tail().

# %%
# Aufgabe 3:

# %% [markdown]
# **Aufgabe 4.** Gib die letzten 3 Zeilen der Tabelle aus.

# %%
# Aufgabe 4:

# %% [markdown]
# **Aufgabe 5.** Finde die Größe der Tabelle heraus (Anzahl der Zeilen und Spalten).
#
# > 💡 Attribut shape.

# %%
# Aufgabe 5:

# %% [markdown]
# **Aufgabe 6.** Gib nur die Anzahl der Zeilen in der Tabelle aus.
#
# > 💡 shape[0] gibt die erste Zahl zurück.

# %%
# Aufgabe 6:

# %% [markdown]
# **Aufgabe 7.** Gib nur die Anzahl der Spalten in der Tabelle aus.
#
# > 💡 shape[1].

# %%
# Aufgabe 7:

# %% [markdown]
# **Aufgabe 8.** Gib die Namen aller Spalten aus.
#
# > 💡 Attribut columns.

# %%
# Aufgabe 8:

# %% [markdown]
# **Aufgabe 9.** Gib allgemeine Informationen über die Tabelle aus (Datentypen, Anzahl der Werte).
#
# > 💡 Methode info().

# %%
# Aufgabe 9:

# %% [markdown]
# **Aufgabe 10.** Gib die Statistik zu den numerischen Spalten aus (Durchschnitt, Min, Max usw.).
#
# > 💡 Methode describe().

# %%
# Aufgabe 10:

# %% [markdown]
# **Aufgabe 11.** Gib die Datentypen jeder Spalte aus.
#
# > 💡 Attribut dtypes.

# %%
# Aufgabe 11:

# %% [markdown]
# **Aufgabe 12.** Gib die ersten 7 Zeilen der Tabelle aus.

# %%
# Aufgabe 12:

# %% [markdown]
# **Aufgabe 13.** Gib die letzten 10 Zeilen der Tabelle aus.

# %%
# Aufgabe 13:

# %% [markdown]
# **Aufgabe 14.** Wie viele Werte (Zeilen) gibt es insgesamt in der Tabelle? Verwende die Funktion len().

# %%
# Aufgabe 14:

# %% [markdown]
# **Aufgabe 15.** Gib die erste Zeile der Tabelle aus.
#
# > 💡 head(1).

# %%
# Aufgabe 15:

# %% [markdown]
# ## Kapitel 2. Spalten auswählen (Aufgaben 16-30)
#
# Eine Spalte auswählen: `df["col"]`. Mehrere auswählen: `df[["col1", "col2"]]`.

# %% [markdown]
# **Aufgabe 16.** Gib die Spalte `city` aus.

# %%
# Aufgabe 16:

# %% [markdown]
# **Aufgabe 17.** Gib die Spalte `total` aus.

# %%
# Aufgabe 17:

# %% [markdown]
# **Aufgabe 18.** Gib die Spalte `book_title` aus.

# %%
# Aufgabe 18:

# %% [markdown]
# **Aufgabe 19.** Gib die Spalten `city` und `total` zusammen aus.
#
# > 💡 Doppelte Klammern: df[["city", "total"]].

# %%
# Aufgabe 19:

# %% [markdown]
# **Aufgabe 20.** Gib die Spalten `book_title`, `genre` und `unit_price` aus.

# %%
# Aufgabe 20:

# %% [markdown]
# **Aufgabe 21.** Gib die ersten 5 Zeilen der Spalte `genre` aus.
#
# > 💡 Man kann kombinieren: df["genre"].head().

# %%
# Aufgabe 21:

# %% [markdown]
# **Aufgabe 22.** Gib die Spalten `manager` und `total` aus, nur die ersten 10 Zeilen.

# %%
# Aufgabe 22:

# %% [markdown]
# **Aufgabe 23.** Gib die Spalte `rating` aus.

# %%
# Aufgabe 23:

# %% [markdown]
# **Aufgabe 24.** Gib die Spalten `order_id`, `date` und `city` aus.

# %%
# Aufgabe 24:

# %% [markdown]
# **Aufgabe 25.** Gib die ersten 3 Zeilen der Spalten `book_title` und `quantity` aus.

# %%
# Aufgabe 25:

# %% [markdown]
# **Aufgabe 26.** Gib die Spalte `channel` aus.

# %%
# Aufgabe 26:

# %% [markdown]
# **Aufgabe 27.** Gib die Spalten `city`, `genre` und `total` aus, die letzten 5 Zeilen.
#
# > 💡 Kombiniere doppelte Klammern und tail().

# %%
# Aufgabe 27:

# %% [markdown]
# **Aufgabe 28.** Gib die Spalte `discount_pct` aus.

# %%
# Aufgabe 28:

# %% [markdown]
# **Aufgabe 29.** Gib die Spalten `unit_price` und `quantity` aus.

# %%
# Aufgabe 29:

# %% [markdown]
# **Aufgabe 30.** Gib die Spalte `quantity` aus, die ersten 8 Zeilen.

# %%
# Aufgabe 30:

# %% [markdown]
# ## Kapitel 3. Grundlegende Aggregate pro Spalte (Aufgaben 31-50)
#
# Befehle: `sum()`, `mean()`, `max()`, `min()`, `count()`, `unique()`, `nunique()`, `value_counts()`.

# %% [markdown]
# **Aufgabe 31.** Berechne die Gesamtsumme aller Bestellungen (Spalte `total`).
#
# > 💡 df["total"].sum().

# %%
# Aufgabe 31:

# %% [markdown]
# **Aufgabe 32.** Berechne den durchschnittlichen Bestellbetrag.
#
# > 💡 mean().

# %%
# Aufgabe 32:

# %% [markdown]
# **Aufgabe 33.** Finde den maximalen Bestellbetrag.
#
# > 💡 max().

# %%
# Aufgabe 33:

# %% [markdown]
# **Aufgabe 34.** Finde den minimalen Bestellbetrag.
#
# > 💡 min().

# %%
# Aufgabe 34:

# %% [markdown]
# **Aufgabe 35.** Berechne, wie viele Bestellungen es insgesamt gibt (verwende count() auf einer beliebigen Spalte).

# %%
# Aufgabe 35:

# %% [markdown]
# **Aufgabe 36.** Finde den durchschnittlichen Buchpreis (`unit_price`).

# %%
# Aufgabe 36:

# %% [markdown]
# **Aufgabe 37.** Finde die maximale Anzahl von Büchern in einer Bestellung (`quantity`).

# %%
# Aufgabe 37:

# %% [markdown]
# **Aufgabe 38.** Berechne die Gesamtzahl der verkauften Bücher (Summe der Spalte `quantity`).

# %%
# Aufgabe 38:

# %% [markdown]
# **Aufgabe 39.** Gib alle eindeutigen Städte aus.
#
# > 💡 Methode unique().

# %%
# Aufgabe 39:

# %% [markdown]
# **Aufgabe 40.** Gib alle eindeutigen Genres aus.

# %%
# Aufgabe 40:

# %% [markdown]
# **Aufgabe 41.** Wie viele eindeutige Städte gibt es in den Daten?
#
# > 💡 Methode nunique().

# %%
# Aufgabe 41:

# %% [markdown]
# **Aufgabe 42.** Wie viele eindeutige Bücher gibt es in den Daten?

# %%
# Aufgabe 42:

# %% [markdown]
# **Aufgabe 43.** Wie viele eindeutige Genres gibt es in den Daten?

# %%
# Aufgabe 43:

# %% [markdown]
# **Aufgabe 44.** Wie viele Bestellungen gibt es aus jeder Stadt? Verwende value_counts().
#
# > 💡 df["city"].value_counts().

# %%
# Aufgabe 44:

# %% [markdown]
# **Aufgabe 45.** Wie viele Bestellungen gibt es in jedem Genre?
#
# > 💡 value_counts() auf der Spalte genre.

# %%
# Aufgabe 45:

# %% [markdown]
# **Aufgabe 46.** Wie viele Bestellungen hat jeder Manager bearbeitet?

# %%
# Aufgabe 46:

# %% [markdown]
# **Aufgabe 47.** Wie viele Bestellungen gibt es über jeden Kanal (`channel`)?

# %%
# Aufgabe 47:

# %% [markdown]
# **Aufgabe 48.** Gib alle eindeutigen Bewertungswerte (`rating`) aus.

# %%
# Aufgabe 48:

# %% [markdown]
# **Aufgabe 49.** Finde die durchschnittliche Bewertung (`rating`).

# %%
# Aufgabe 49:

# %% [markdown]
# **Aufgabe 50.** Finde den durchschnittlichen Rabatt (`discount_pct`).

# %%
# Aufgabe 50:

# %% [markdown]
# ## Kapitel 4. Filterung — eine Bedingung (Aufgaben 51-70)
#
# Prinzip: `df[df["Spalte"] Bedingung]`. Zum Beispiel: `df[df["total"] > 500]`.

# %% [markdown]
# **Aufgabe 51.** Gib alle Bestellungen aus der Stadt Kyiv aus.
#
# > 💡 df[df["city"] == "Kyiv"].

# %%
# Aufgabe 51:

# %% [markdown]
# **Aufgabe 52.** Gib alle Bestellungen aus der Stadt Lviv aus.

# %%
# Aufgabe 52:

# %% [markdown]
# **Aufgabe 53.** Gib alle Bestellungen aus der Stadt Odesa aus.

# %%
# Aufgabe 53:

# %% [markdown]
# **Aufgabe 54.** Gib alle Bestellungen des Genres `Fantasy` aus.

# %%
# Aufgabe 54:

# %% [markdown]
# **Aufgabe 55.** Gib alle Bestellungen des Genres `Detective` aus.

# %%
# Aufgabe 55:

# %% [markdown]
# **Aufgabe 56.** Gib alle Bestellungen des Genres `Children's` aus.

# %%
# Aufgabe 56:

# %% [markdown]
# **Aufgabe 57.** Gib die Bestellungen aus, bei denen der Betrag (`total`) größer als 500 ist.

# %%
# Aufgabe 57:

# %% [markdown]
# **Aufgabe 58.** Gib die Bestellungen aus, bei denen der Betrag (`total`) größer als 1000 ist.

# %%
# Aufgabe 58:

# %% [markdown]
# **Aufgabe 59.** Gib die Bestellungen aus, bei denen der Betrag (`total`) kleiner als 200 ist.

# %%
# Aufgabe 59:

# %% [markdown]
# **Aufgabe 60.** Gib die Bestellungen aus, bei denen die Anzahl der Bücher (`quantity`) gleich 5 ist.

# %%
# Aufgabe 60:

# %% [markdown]
# **Aufgabe 61.** Gib die Bestellungen aus, bei denen die Anzahl der Bücher größer als 3 ist.

# %%
# Aufgabe 61:

# %% [markdown]
# **Aufgabe 62.** Gib die Bestellungen mit einer Bewertung (`rating`) von 5 aus.

# %%
# Aufgabe 62:

# %% [markdown]
# **Aufgabe 63.** Gib die Bestellungen mit einer Bewertung unter 4 aus.

# %%
# Aufgabe 63:

# %% [markdown]
# **Aufgabe 64.** Gib die Bestellungen des Buches `Dune` aus.
#
# > 💡 df[df["book_title"] == "Dune"].

# %%
# Aufgabe 64:

# %% [markdown]
# **Aufgabe 65.** Gib die Bestellungen des Buches `1984` aus.

# %%
# Aufgabe 65:

# %% [markdown]
# **Aufgabe 66.** Gib die Bestellungen aus, die über den Kanal `Website` aufgegeben wurden.

# %%
# Aufgabe 66:

# %% [markdown]
# **Aufgabe 67.** Gib die Bestellungen aus, die über den Kanal `Phone` aufgegeben wurden.

# %%
# Aufgabe 67:

# %% [markdown]
# **Aufgabe 68.** Gib die Bestellungen der Managerin `Iryna` aus.

# %%
# Aufgabe 68:

# %% [markdown]
# **Aufgabe 69.** Gib die Bestellungen aus, bei denen ein Rabatt angewendet wurde (`discount_pct` größer als 0).

# %%
# Aufgabe 69:

# %% [markdown]
# **Aufgabe 70.** Gib die Bestellungen aus, bei denen der Buchpreis (`unit_price`) gleich oder größer als 400 ist.

# %%
# Aufgabe 70:

# %% [markdown]
# ## Kapitel 5. Filterung + Zählen (Aufgaben 71-80)
#
# Wir kombinieren einen Filter mit `len()` oder Aggregaten, um sofort eine Zahl zu erhalten.

# %% [markdown]
# **Aufgabe 71.** Wie viele Bestellungen gibt es aus der Stadt Kyiv?
#
# > 💡 Umgib den Filter mit len(): len(df[df["city"] == "Kyiv"]).

# %%
# Aufgabe 71:

# %% [markdown]
# **Aufgabe 72.** Wie viele Bestellungen des Genres `Science` gibt es?

# %%
# Aufgabe 72:

# %% [markdown]
# **Aufgabe 73.** Wie viele Bestellungen mit einem Betrag über 800 gibt es?

# %%
# Aufgabe 73:

# %% [markdown]
# **Aufgabe 74.** Wie hoch ist der Gesamtumsatz (`total`) aus der Stadt Lviv?
#
# > 💡 Filtere Lviv, nimm dann ["total"].sum().

# %%
# Aufgabe 74:

# %% [markdown]
# **Aufgabe 75.** Wie hoch ist der Gesamtumsatz aus dem Genre `Business`?

# %%
# Aufgabe 75:

# %% [markdown]
# **Aufgabe 76.** Wie hoch ist der durchschnittliche Bestellbetrag in der Stadt Odesa?

# %%
# Aufgabe 76:

# %% [markdown]
# **Aufgabe 77.** Wie viele Bestellungen mit der Bewertung 5 gibt es?

# %%
# Aufgabe 77:

# %% [markdown]
# **Aufgabe 78.** Wie viele Bücher (`quantity`) wurden in der Stadt Kharkiv verkauft?
#
# > 💡 Filter + ["quantity"].sum().

# %%
# Aufgabe 78:

# %% [markdown]
# **Aufgabe 79.** Wie hoch ist die durchschnittliche Bewertung der Bestellungen über den Kanal `Mobile App`?

# %%
# Aufgabe 79:

# %% [markdown]
# **Aufgabe 80.** Wie viele Bestellungen hat die Managerin `Sofia` bearbeitet?

# %%
# Aufgabe 80:

# %% [markdown]
# ## Kapitel 6. Filterung — mehrere Bedingungen (Aufgaben 81-95)
#
# Wir kombinieren Bedingungen mit `&` (UND) und `|` (ODER). Jede Bedingung kommt in Klammern!
# Zum Beispiel: `df[(df["city"] == "Kyiv") & (df["total"] > 500)]`.

# %% [markdown]
# **Aufgabe 81.** Gib die Bestellungen aus Kyiv aus, bei denen der Betrag größer als 500 ist.
#
# > 💡 Zwei Bedingungen mit &, jede in Klammern.

# %%
# Aufgabe 81:

# %% [markdown]
# **Aufgabe 82.** Gib die Bestellungen des Genres `Fantasy` mit einem Betrag über 600 aus.

# %%
# Aufgabe 82:

# %% [markdown]
# **Aufgabe 83.** Gib die Bestellungen aus Lviv mit einer Bewertung von 5 aus.

# %%
# Aufgabe 83:

# %% [markdown]
# **Aufgabe 84.** Gib die Bestellungen aus, bei denen das Genre `Detective` ODER `Fantasy` ist.
#
# > 💡 Verwende | (ODER).

# %%
# Aufgabe 84:

# %% [markdown]
# **Aufgabe 85.** Gib die Bestellungen aus den Städten Kyiv ODER Odesa aus.

# %%
# Aufgabe 85:

# %% [markdown]
# **Aufgabe 86.** Gib die Bestellungen aus, bei denen die Anzahl der Bücher größer als 2 ist UND ein Rabatt angewendet wurde (>0).

# %%
# Aufgabe 86:

# %% [markdown]
# **Aufgabe 87.** Gib die Bestellungen aus Kharkiv über den Kanal `Website` aus.

# %%
# Aufgabe 87:

# %% [markdown]
# **Aufgabe 88.** Gib die Bestellungen des Managers `Oleg` mit einem Betrag über 700 aus.

# %%
# Aufgabe 88:

# %% [markdown]
# **Aufgabe 89.** Gib die Bestellungen des Buches `Harry Potter` mit einer Bewertung von 5 aus.

# %%
# Aufgabe 89:

# %% [markdown]
# **Aufgabe 90.** Gib die Bestellungen aus, bei denen der Preis (`unit_price`) zwischen 200 und 300 liegt (größer oder gleich 200 UND kleiner oder gleich 300).

# %%
# Aufgabe 90:

# %% [markdown]
# **Aufgabe 91.** Gib die Bestellungen mit einer Bewertung von 4 ODER 5 aus.

# %%
# Aufgabe 91:

# %% [markdown]
# **Aufgabe 92.** Gib die Bestellungen des Genres `Science` aus der Stadt Kyiv aus.

# %%
# Aufgabe 92:

# %% [markdown]
# **Aufgabe 93.** Gib die Bestellungen mit einem Rabatt von 10% oder 15% aus.
#
# > 💡 Zwei Bedingungen mit |.

# %%
# Aufgabe 93:

# %% [markdown]
# **Aufgabe 94.** Gib die Bestellungen über den Kanal `Phone` mit einem Betrag unter 300 aus.

# %%
# Aufgabe 94:

# %% [markdown]
# **Aufgabe 95.** Wie viele Bestellungen aus Kyiv mit einem Betrag über 500 gibt es?
#
# > 💡 Kombiniere den Filter aus mehreren Bedingungen mit len().

# %%
# Aufgabe 95:

# %% [markdown]
# ## Kapitel 7. Neue Spalten erstellen (Aufgaben 96-105)
#
# Neue Spalte: `df["neuer_name"] = Ausdruck`. Operationen werden sofort auf die gesamte Spalte angewendet.

# %% [markdown]
# **Aufgabe 96.** Erstelle die Spalte `full_price`, die gleich `unit_price` × `quantity` ist (Preis ohne Rabatt).

# %%
# Aufgabe 96:

# %% [markdown]
# **Aufgabe 97.** Erstelle die Spalte `discount_amount` = `full_price` − `total` (wie viel durch den Rabatt gespart wurde).
#
# > 💡 Führe zuerst die vorherige Aufgabe aus, damit die Spalte full_price existiert.

# %%
# Aufgabe 97:

# %% [markdown]
# **Aufgabe 98.** Erstelle die Spalte `price_with_tax`, die gleich `total` erhöht um 5% ist (multipliziere mit 1.05).

# %%
# Aufgabe 98:

# %% [markdown]
# **Aufgabe 99.** Erstelle die Spalte `is_big`, die `True` ist, wenn `total` größer als 700 ist.
#
# > 💡 df["is_big"] = df["total"] > 700.

# %%
# Aufgabe 99:

# %% [markdown]
# **Aufgabe 100.** Erstelle die Spalte `is_discounted`, die `True` ist, wenn `discount_pct` größer als 0 ist.

# %%
# Aufgabe 100:

# %% [markdown]
# **Aufgabe 101.** Erstelle die Spalte `total_uah_rounded` — den auf ganze Zahlen gerundeten Bestellbetrag.
#
# > 💡 Verwende .round() auf der Spalte.

# %%
# Aufgabe 101:

# %% [markdown]
# **Aufgabe 102.** Erstelle die Spalte `books_per_order`, die `quantity` dupliziert (kopiere einfach die Spalte in eine neue).

# %%
# Aufgabe 102:

# %% [markdown]
# **Aufgabe 103.** Erstelle die Spalte `high_rating`, die `True` ist, wenn die Bewertung gleich 5 ist.

# %%
# Aufgabe 103:

# %% [markdown]
# **Aufgabe 104.** Erstelle die Spalte `revenue_per_book` = `total` ÷ `quantity` (durchschnittlicher Preis pro Buch in der Bestellung).

# %%
# Aufgabe 104:

# %% [markdown]
# **Aufgabe 105.** Erstelle die Spalte `city_upper`, in der der Stadtname in Großbuchstaben geschrieben ist.
#
# > 💡 Für Text: df["city"].str.upper().

# %%
# Aufgabe 105:

# %% [markdown]
# ## Kapitel 8. Sortieren (Aufgaben 106-112)
#
# `df.sort_values("Spalte")` — aufsteigend, `ascending=False` — absteigend.

# %% [markdown]
# **Aufgabe 106.** Sortiere die Tabelle nach dem Betrag (`total`) vom größten zum kleinsten. Gib die ersten 5 aus.
#
# > 💡 sort_values mit ascending=False.

# %%
# Aufgabe 106:

# %% [markdown]
# **Aufgabe 107.** Sortiere die Tabelle nach dem Betrag (`total`) vom kleinsten zum größten. Gib die ersten 5 aus.

# %%
# Aufgabe 107:

# %% [markdown]
# **Aufgabe 108.** Sortiere die Tabelle nach dem Buchpreis (`unit_price`) absteigend. Gib die ersten 10 aus.

# %%
# Aufgabe 108:

# %% [markdown]
# **Aufgabe 109.** Sortiere die Tabelle nach der Anzahl der Bücher (`quantity`) absteigend. Gib die ersten 5 aus.

# %%
# Aufgabe 109:

# %% [markdown]
# **Aufgabe 110.** Sortiere die Tabelle nach der Bewertung (`rating`) aufsteigend. Gib die ersten 5 aus.

# %%
# Aufgabe 110:

# %% [markdown]
# **Aufgabe 111.** Finde die 3 teuersten Bestellungen (nach `total`).
#
# > 💡 Sortiere absteigend und nimm head(3).

# %%
# Aufgabe 111:

# %% [markdown]
# **Aufgabe 112.** Finde die 3 günstigsten Bestellungen (nach `total`).

# %%
# Aufgabe 112:

# %% [markdown]
# ## Kapitel 9. Gruppieren — groupby (Aufgaben 113-120)
#
# Schema: `df.groupby("Spalte")["was_berechnen"].Aggregat()`.

# %% [markdown]
# **Aufgabe 113.** Berechne den Gesamtumsatz (`total`) für jede Stadt.
#
# > 💡 df.groupby("city")["total"].sum().

# %%
# Aufgabe 113:

# %% [markdown]
# **Aufgabe 114.** Berechne den durchschnittlichen Bestellbetrag für jedes Genre.
#
# > 💡 groupby genre, dann mean().

# %%
# Aufgabe 114:

# %% [markdown]
# **Aufgabe 115.** Berechne die Anzahl der Bestellungen für jeden Manager.
#
# > 💡 groupby manager, dann count() auf einer beliebigen Spalte.

# %%
# Aufgabe 115:

# %% [markdown]
# **Aufgabe 116.** Berechne die Gesamtzahl der verkauften Bücher (`quantity`) für jedes Genre.

# %%
# Aufgabe 116:

# %% [markdown]
# **Aufgabe 117.** Berechne die durchschnittliche Bewertung (`rating`) für jeden Kanal (`channel`).

# %%
# Aufgabe 117:

# %% [markdown]
# **Aufgabe 118.** Finde den Gesamtumsatz nach Genres und sortiere absteigend.
#
# > 💡 Füge nach groupby().sum() .sort_values(ascending=False) hinzu.

# %%
# Aufgabe 118:

# %% [markdown]
# **Aufgabe 119.** Berechne den durchschnittlichen, minimalen und maximalen Bestellbetrag nach Städten.
#
# > 💡 Verwende .agg(["mean", "min", "max"]).

# %%
# Aufgabe 119:

# %% [markdown]
# **Aufgabe 120.** Berechne den Gesamtumsatz nach zwei Spalten gleichzeitig: Stadt und Genre.
#
# > 💡 groupby(["city", "genre"]).

# %%
# Aufgabe 120:

# %% [markdown]
# ---
#
# # 🎉 Fertig!
#
# Wenn du alle 120 Aufgaben durchgearbeitet hast — herzlichen Glückwunsch! Du hast die gesamte pandas-Grundsyntax geübt:
#
# - ✅ Erster Blick auf die Daten (`head`, `tail`, `shape`, `info`, `describe`)
# - ✅ Spalten auswählen
# - ✅ Aggregate (`sum`, `mean`, `max`, `min`, `unique`, `value_counts`, `nunique`)
# - ✅ Filterung (eine Bedingung und mehrere Bedingungen)
# - ✅ Neue Spalten erstellen
# - ✅ Sortieren
# - ✅ Gruppieren (`groupby`)
#
# ### Tipp
# Der beste Weg, das Gelernte zu festigen: kehre nach ein paar Tagen zurück und arbeite die Aufgaben noch einmal durch, ohne nachzuschauen. Was anfangs Nachdenken erforderte, wird automatisch.
#
# **Weiter so! 🐼**
